# %%
# imports 
import numpy as np
import pandas as pd 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.datasets import fetch_california_housing
from sklearn.metrics import mean_squared_error

# %%
df = fetch_california_housing()

# %%
features = pd.DataFrame(data.data,columns=data.feature_names)

# %%
target = pd.DataFrame(data.target,columns=data.target_names)

# %%
target.head(5)
# Out:
#    MedHouseVal
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422

# %%
X_train,X_test,y_train, y_test = train_test_split(features,target,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
lr = LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %%
lr.fit(X_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test_scaled)

# %%
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error on Test Data: {mse}')
# Out:
# Mean Squared Error on Test Data: 0.5558915986952442

# %%
# Eg

# %%
# Example: Predict the price for a new house
new_house = pd.DataFrame({
    'MedInc': [3.0],  # Example numerical features, use appropriate values from the dataset
    'HouseAge': [20.0],
    'AveRooms': [5.0],
    'AveBedrms': [2.0],
    'Population': [1000.0],
    'AveOccup': [3.0],
    'Latitude': [37.5],
    'Longitude': [-122.5],
    
})


# Make predictions for the new house
predicted_price = lr.predict(new_house) * 100000
# Out:
# /home/unique/anaconda3/lib/python3.12/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
# Scale the new house data
new_house_scaled = scaler.transform(new_house)

# Predict
predicted_price = lr.predict(new_house_scaled) * 100000

# Format output
predicted_price_value = float(predicted_price.flatten()[0])
print(f'Predicted Price for the New House: ${predicted_price_value:.2f}')
# Out:
# Predicted Price for the New House: $284131.64

# %%
# exporting model using pickle

# %%
import pickle 
with open('model_pickle','wb') as f:
    pickle.dump(lr,f)

# %%
with open('model_pickle','rb') as f:
    mp = pickle.load(f)

# %%
mp.predict(new_house_scaled) * 100000
# Out:
# array([[284131.64077207]])

# %%
# using joblib

# %%
import joblib

# %%
joblib.dump(lr,'mymodel_jooblib')
# Out:
# ['mymodel_jooblib']

# %%
mj= joblib.load('mymodel_jooblib')

# %%
mj.predict(new_house_scaled) * 100000
# Out:
# array([[284131.64077207]])

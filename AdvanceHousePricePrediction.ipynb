# %% [markdown]
# ## House Prices : Advance Regression Technique

# %% [markdown]
# Data Analysis Life Cycle
# - Data Analysis
# - Feature Engineering
# - Feature Selection
# - Model Building
# - Model Deployment

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('datasets/House_train.csv')

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# In Data Analysis we will Analyze to find out the below stuff
# 1. Missing Values
# 2. All the Numerical Variables
# 3. Distriibution of the Numerical variables
# 4. Categorical Variables
# 5. Cardibality of ategorical variables
# 6. Outliers
# 7. Realationship betwen independent and dependent features

# %% [markdown]
# ### Missing Values

# %%
features_with_na = [feature for feature in dataset.columns if dataset[feature].isnull().sum()]

# %%
for feature in features_with_na:
    print(feature,np.round(dataset[feature].isnull().mean()),4)
# Out:
# LotFrontage 0.0 4
# Alley 1.0 4
# MasVnrType 1.0 4
# MasVnrArea 0.0 4
# BsmtQual 0.0 4
# BsmtCond 0.0 4
# BsmtExposure 0.0 4
# BsmtFinType1 0.0 4
# BsmtFinType2 0.0 4
# Electrical 0.0 4
# FireplaceQu 0.0 4
# GarageType 0.0 4
# GarageYrBlt 0.0 4
# GarageFinish 0.0 4
# GarageQual 0.0 4
# GarageCond 0.0 4
# PoolQC 1.0 4
# Fence 1.0 4
# MiscFeature 1.0 4

# %%
# Since there are many missing value we need to finda teh realtionship etween missing values and sales price
for feature in features_with_na:
    data[feature] = np.where(data[feature].isnull(),1,0)

    data.groupby
